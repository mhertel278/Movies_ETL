# %%
import json
import pandas as pd
import numpy as np
from pprint import pprint
import re

# %%
file_dir = "C://Users/user/Desktop/Data Bootcamp Analysis Projects/8th Module/"

# %%
with open(f"{file_dir}wikipedia-movies.json", mode='r') as file:
    wiki_movies_raw = json.load(file)

# %%
len(wiki_movies_raw)
# Out:
# 7311

# %%
pprint(wiki_movies_raw[:5])
# Out:
# [{'Based on': ['Characters', 'by Rex Weiner'],
#   'Box office': '$21.4 million',
#   'Budget': '$20 million',
#   'Cinematography': 'Oliver Wood',
#   'Country': 'United States',
#   'Directed by': 'Renny Harlin',
#   'Distributed by': '20th Century Fox',
#   'Edited by': 'Michael Tronick',
#   'Language': 'English',
#   'Music by': ['Cliff Eidelman', 'Yello'],
#   'Narrated by': 'Andrew "Dice" Clay',
#   'Produced by': ['Steve Perry', 'Joel Silver'],
#   'Productioncompany ': 'Silver Pictures',
#   'Release date': ['July 11, 1990', '(', '1990-07-11', ')'],
#   'Running time': '102 minutes',
#   'Screenplay by': ['David Arnott', 'James Cappe', 'Daniel Waters'],
#   'Starring': ['Andrew Dice Clay',
#                'Wayne Newton',
#                'Priscilla Presley',
#                'Lauren Holly',
#                'Morris Day',
#                'Robert Englund',
#                "Ed O'Neill"],
#   'Story by': ['David Arnott', 'James Cappe'],
# ...

# %%
pprint(wiki_movies_raw[-5:])
# Out:
# [{'Based on': ['Sherlock Holmes',
#                'and',
#                'Dr. Watson',
#                'by',
#                'Sir Arthur Conan Doyle'],
#   'Box office': '$41.9 million',
#   'Budget': '$42 million',
#   'Cinematography': 'Oliver Wood',
#   'Country': 'United States',
#   'Directed by': 'Etan Cohen',
#   'Distributed by': 'Sony Pictures Releasing',
#   'Edited by': 'Dean Zimmerman',
#   'Language': 'English',
#   'Music by': 'Mark Mothersbaugh',
#   'Produced by': ['Will Ferrell',
#                   'Adam McKay',
#                   'Jimmy Miller',
#                   'Clayton Townsend'],
#   'Productioncompanies ': ['Columbia Pictures',
#                            'Gary Sanchez Productions',
#                            'Mosaic Media Group',
#                            'Mimran Schur Pictures'],
#   'Release date': ['December 25, 2018',
#                    '(',
#                    '2018-12-25',
#                    ')',
# ...

# %%
kaggle_meta_data = pd.read_csv(f"{file_dir}movies_metadata.csv", low_memory=False)
ratings = pd.read_csv(f"{file_dir}ratings.csv")

# %%
wiki_movies_df = pd.DataFrame(wiki_movies_raw)
wiki_movies_df.head()
# Out:
#                                                  url    year  \
# 0  https://en.wikipedia.org/wiki/The_Adventures_o...  1990.0
# 1  https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990.0
# 2   https://en.wikipedia.org/wiki/Air_America_(film)  1990.0
# 3    https://en.wikipedia.org/wiki/Alice_(1990_film)  1990.0
# 4      https://en.wikipedia.org/wiki/Almost_an_Angel  1990.0
#
#                                imdb_link                            title  \
# 0  https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1  https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2  https://www.imdb.com/title/tt0099005/                      Air America
# 3  https://www.imdb.com/title/tt0099012/                            Alice
# 4  https://www.imdb.com/title/tt0099018/                  Almost an Angel
#
#           Directed by                  Produced by  \
# 0        Renny Harlin   [Steve Perry, Joel Silver]
# ...

# %%
wiki_movies_df.columns.tolist()
# Out:
# ['url',
#  'year',
#  'imdb_link',
#  'title',
#  'Directed by',
#  'Produced by',
#  'Screenplay by',
#  'Story by',
#  'Based on',
#  'Starring',
#  'Narrated by',
#  'Music by',
#  'Cinematography',
#  'Edited by',
#  'Productioncompany ',
#  'Distributed by',
#  'Release date',
#  'Running time',
#  'Country',
#  'Language',
#  'Budget',
#  'Box office',
#  'Written by',
#  'Genre',
#  'Theme music composer',
#  'Country of origin',
#  'Original language(s)',
#  'Producer(s)',
#  'Editor(s)',
#  'Production company(s)',
#  'Original network',
#  'Original release',
#  'Productioncompanies ',
#  'Executive producer(s)',
#  'Production location(s)',
#  'Distributor',
#  'Picture format',
#  'Audio format',
#  'Voices of',
#  'Followed by',
#  'Composer(s)',
#  'Created by',
#  'Also known as',
#  'Opening theme',
#  'No. of episodes',
#  'Preceded by',
#  'Author',
#  'Publisher',
#  'Publication date',
#  'Media type',
#  'Pages',
#  'ISBN',
#  'OCLC',
#  'LC Class',
# ...

# %%
wiki_movies = [movie for movie in wiki_movies_raw
              if ("Director" in movie or "Directed by" in movie)
              and "imdb_link" in movie]
len(wiki_movies)
# Out:
# 7080

# %%
wiki_movies_df2 = pd.DataFrame(wiki_movies)
wiki_movies_df2.head()
# Out:
#                                                  url  year  \
# 0  https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1  https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2   https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3    https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4      https://en.wikipedia.org/wiki/Almost_an_Angel  1990
#
#                                imdb_link                            title  \
# 0  https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1  https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2  https://www.imdb.com/title/tt0099005/                      Air America
# 3  https://www.imdb.com/title/tt0099012/                            Alice
# 4  https://www.imdb.com/title/tt0099018/                  Almost an Angel
#
#           Directed by                  Produced by  \
# 0        Renny Harlin   [Steve Perry, Joel Silver]
# 1         James Foley  [Ric Kidney, Robert Redlin]
# ...

# %%
wiki_movies_df2.columns.tolist()
# Out:
# ['url',
#  'year',
#  'imdb_link',
#  'title',
#  'Directed by',
#  'Produced by',
#  'Screenplay by',
#  'Story by',
#  'Based on',
#  'Starring',
#  'Narrated by',
#  'Music by',
#  'Cinematography',
#  'Edited by',
#  'Productioncompany ',
#  'Distributed by',
#  'Release date',
#  'Running time',
#  'Country',
#  'Language',
#  'Budget',
#  'Box office',
#  'Written by',
#  'Genre',
#  'Theme music composer',
#  'Country of origin',
#  'Original language(s)',
#  'Producer(s)',
#  'Editor(s)',
#  'Production company(s)',
#  'Original network',
#  'Original release',
#  'Productioncompanies ',
#  'Executive producer(s)',
#  'Production location(s)',
#  'Distributor',
#  'Picture format',
#  'Audio format',
#  'Voices of',
#  'Followed by',
#  'Composer(s)',
#  'Created by',
#  'Also known as',
#  'Opening theme',
#  'No. of episodes',
#  'Preceded by',
#  'Adaptation by',
#  'Suggested by',
#  'Traditional',
#  'Mandarin',
#  'Released',
#  'Recorded',
#  'Venue',
#  'Length',
# ...

# %%
# filter to only movies with a director, an imdb_link, and no No. of episodes (removing tv shows)

wiki_movies = [movie for movie in wiki_movies_raw
               if ('Director' in movie or 'Directed by' in movie)
               and 'imdb_link' in movie
               and 'No. of episodes' not in movie]
len(wiki_movies)
# Out:
# 7076

# %%
wiki_movies_df = pd.DataFrame(wiki_movies)
wiki_movies_df.tail(2)
# Out:
#                                                     url  year  \
# 7074  https://en.wikipedia.org/wiki/Destroyer_(2018_...  2018
# 7075  https://en.wikipedia.org/wiki/Black_Mirror:_Ba...  2018
#
#                                   imdb_link         title   Directed by  \
# 7074  https://www.imdb.com/title/tt7137380/     Destroyer  Karyn Kusama
# 7075  https://www.imdb.com/title/tt9495224/  Bandersnatch   David Slade
#
#                                  Produced by Screenplay by Story by Based on  \
# 7074  [Fred Berger, Phil Hay, Matt Manfredi]           NaN      NaN      NaN
# 7075                          Russell McLean           NaN      NaN      NaN
#
#                                                Starring  ... Hepburn  \
# 7074  [Nicole Kidman, Sebastian Stan, Toby Kebbell, ...  ...     NaN
# 7075  [Fionn Whitehead, Will Poulter, Craig Parkinso...  ...     NaN
#
#      Literally Cantonese Chinese Yiddish Arabic Romanized Russian Hebrew  \
# ...

# %%
wiki_movies_df[wiki_movies_df['Arabic'].notnull()]
# Out:
#                                                   url  year  \
# 6834  https://en.wikipedia.org/wiki/The_Insult_(film)  2018
# 7058   https://en.wikipedia.org/wiki/Capernaum_(film)  2018
#
#                                   imdb_link       title    Directed by  \
# 6834  https://www.imdb.com/title/tt7048622/  The Insult   Ziad Doueiri
# 7058  https://www.imdb.com/title/tt8267604/   Capernaum  Nadine Labaki
#
#                                             Produced by  \
# 6834  [Rachid Bouchareb, Jean Bréhat, Julie Gayet, A...
# 7058                    [Michel Merkt, Khaled Mouzanar]
#
#                                           Screenplay by  \
# 6834                                                NaN
# 7058  [Nadine Labaki, Jihad Hojaily, Michelle Keserw...
#
#                                                Story by Based on  \
# 6834                                                NaN      NaN
# 7058  [Georges Khabbaz, Nadine Labaki, Michelle Kese...      NaN
#
# ...

# %%
wiki_movies_df[wiki_movies_df['Country'].notnull()]
# Out:
#                                                     url  year  \
# 0     https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1     https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2      https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3       https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4         https://en.wikipedia.org/wiki/Almost_an_Angel  1990
# ...                                                 ...   ...
# 7071    https://en.wikipedia.org/wiki/Holmes_%26_Watson  2018
# 7072     https://en.wikipedia.org/wiki/Vice_(2018_film)  2018
# 7073  https://en.wikipedia.org/wiki/On_the_Basis_of_Sex  2018
# 7074  https://en.wikipedia.org/wiki/Destroyer_(2018_...  2018
# 7075  https://en.wikipedia.org/wiki/Black_Mirror:_Ba...  2018
#
#                                   imdb_link                            title  \
# 0     https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# ...

# %%
wiki_movies_df[wiki_movies_df['year'].notnull()]['url']
# Out:
# 0       https://en.wikipedia.org/wiki/The_Adventures_o...
# 1       https://en.wikipedia.org/wiki/After_Dark,_My_S...
# 2        https://en.wikipedia.org/wiki/Air_America_(film)
# 3         https://en.wikipedia.org/wiki/Alice_(1990_film)
# 4           https://en.wikipedia.org/wiki/Almost_an_Angel
#                               ...
# 7071      https://en.wikipedia.org/wiki/Holmes_%26_Watson
# 7072       https://en.wikipedia.org/wiki/Vice_(2018_film)
# 7073    https://en.wikipedia.org/wiki/On_the_Basis_of_Sex
# 7074    https://en.wikipedia.org/wiki/Destroyer_(2018_...
# 7075    https://en.wikipedia.org/wiki/Black_Mirror:_Ba...
# Name: url, Length: 7076, dtype: object

# %%
sorted(wiki_movies_df.columns.tolist())
# Out:
# ['Adaptation by',
#  'Also known as',
#  'Animation by',
#  'Arabic',
#  'Audio format',
#  'Based on',
#  'Box office',
#  'Budget',
#  'Cantonese',
#  'Chinese',
#  'Cinematography',
#  'Color process',
#  'Composer(s)',
#  'Country',
#  'Country of origin',
#  'Created by',
#  'Directed by',
#  'Director',
#  'Distributed by',
#  'Distributor',
#  'Edited by',
#  'Editor(s)',
#  'Executive producer(s)',
#  'Followed by',
#  'French',
#  'Genre',
#  'Hangul',
#  'Hebrew',
#  'Hepburn',
#  'Japanese',
#  'Label',
#  'Language',
#  'Length',
#  'Literally',
#  'Mandarin',
#  'McCune–Reischauer',
#  'Music by',
#  'Narrated by',
#  'Original language(s)',
#  'Original network',
#  'Original release',
#  'Original title',
#  'Picture format',
#  'Polish',
#  'Preceded by',
#  'Produced by',
#  'Producer',
#  'Producer(s)',
#  'Production company(s)',
#  'Production location(s)',
#  'Productioncompanies ',
#  'Productioncompany ',
#  'Recorded',
#  'Release date',
#  'Released',
# ...

# %%
wiki_movies_df['title'].value_counts()
# Out:
# Beauty and the Beast    4
# The Three Musketeers    3
# The Cremaster Cycle     3
# Titanic                 3
# Masterminds             3
#                        ..
# Ted                     1
# The Switch              1
# Lost in Translation     1
# Palindromes             1
# The Pacifier            1
# Name: title, Length: 6948, dtype: int64

# %%
alternate_titles_columns =['Arabic','Also known as','Cantonese','Chinese','French','Hangul','Hebrew','Hepburn','Japanese',
                          'Literally','Mandarin','McCune–Reischauer','Original title','Polish','Revised Romanization','Romanized',
                           'Russian','Simplified','Traditional','Yiddish']

# %%
# create function to clean the data
def clean_movie(movie):
    # make copy of the movie within the function to preserve the original
    movie = dict(movie)
    # create empty dictionary to hold type of alt title as key and title as value
    alt_titles = {}
    # loop over the list of alternate title types to find if each type is in movie
    for key in alternate_titles_columns:
        if key in movie:
            # add the type and title to alt_titles as a key value pair
            alt_titles[key] = movie[key]
            # remove from movie
            movie.pop(key)
    # if there are alt_titles, add alt_titles to movie
    if len(alt_titles) > 0:
        movie['alt_titles'] = alt_titles
    
    return movie

# %%
# make list of cleaned movies
cleaned_movies = [clean_movie(movie) for movie in wiki_movies]

# %%
wiki_movies_df = pd.DataFrame(cleaned_movies)
sorted(wiki_movies_df.columns.tolist())
# Out:
# ['Adaptation by',
#  'Animation by',
#  'Audio format',
#  'Based on',
#  'Box office',
#  'Budget',
#  'Cinematography',
#  'Color process',
#  'Composer(s)',
#  'Country',
#  'Country of origin',
#  'Created by',
#  'Directed by',
#  'Director',
#  'Distributed by',
#  'Distributor',
#  'Edited by',
#  'Editor(s)',
#  'Executive producer(s)',
#  'Followed by',
#  'Genre',
#  'Label',
#  'Language',
#  'Length',
#  'Music by',
#  'Narrated by',
#  'Original language(s)',
#  'Original network',
#  'Original release',
#  'Picture format',
#  'Preceded by',
#  'Produced by',
#  'Producer',
#  'Producer(s)',
#  'Production company(s)',
#  'Production location(s)',
#  'Productioncompanies ',
#  'Productioncompany ',
#  'Recorded',
#  'Release date',
#  'Released',
#  'Running time',
#  'Screen story by',
#  'Screenplay by',
#  'Starring',
#  'Story by',
#  'Suggested by',
#  'Theme music composer',
#  'Venue',
#  'Voices of',
#  'Written by',
#  'alt_titles',
#  'imdb_link',
#  'title',
# ...

# %%
# create function to clean the data
def clean_movie(movie):
    # make copy of the movie within the function to preserve the original
    movie = dict(movie)
    # create empty dictionary to hold type of alt title as key and title as value
    alt_titles = {}
    # loop over the list of alternate title types to find if each type is in movie
    for key in alternate_titles_columns:
        if key in movie:
            # add the type and title to alt_titles as a key value pair
            alt_titles[key] = movie[key]
            # remove from movie
            movie.pop(key)
    # if there are alt_titles, add alt_titles to movie
    if len(alt_titles) > 0:
        movie['alt_titles'] = alt_titles
    
    # Merge equivalent column names
    def change_column_name(old_name, new_name):
        if old_name in movie:
            movie[new_name] = movie.pop(old_name)
    change_column_name('Directed by', 'Director')
    change_column_name('Adaptation by', 'Writer(s)')
    change_column_name('Country of origin','Country')
    change_column_name('Distributed by','Distributor')
    change_column_name('Edited by', 'Editor(s)')
    change_column_name('Music by', 'Composer(s)')
    change_column_name('Original release', 'Release date')
    change_column_name('Produced by', 'Producer(s)')
    change_column_name('Producer', 'Producer(s)')
    change_column_name('Productioncompanies ', 'Production company(s)')
    change_column_name('Productioncompany ', 'Production company(s)')
    change_column_name('Released', 'Release date')
    change_column_name('Running time', 'Length')
    change_column_name('Screen story by', 'Story by')
    change_column_name('Screenplay by', 'Writer(s)')
    change_column_name('Theme music composer', 'Composer(s)')
    change_column_name('Voices of', 'Starring')
    change_column_name('Written by', 'Writer(s)')
    
    return movie

# %%
# make list of cleaned movies
cleaned_movies = [clean_movie(movie) for movie in wiki_movies]

# %%
wiki_movies_df = pd.DataFrame(cleaned_movies)
sorted(wiki_movies_df.columns.tolist())
# Out:
# ['Animation by',
#  'Audio format',
#  'Based on',
#  'Box office',
#  'Budget',
#  'Cinematography',
#  'Color process',
#  'Composer(s)',
#  'Country',
#  'Created by',
#  'Director',
#  'Distributor',
#  'Editor(s)',
#  'Executive producer(s)',
#  'Followed by',
#  'Genre',
#  'Label',
#  'Language',
#  'Length',
#  'Narrated by',
#  'Original language(s)',
#  'Original network',
#  'Picture format',
#  'Preceded by',
#  'Producer(s)',
#  'Production company(s)',
#  'Production location(s)',
#  'Recorded',
#  'Release date',
#  'Starring',
#  'Story by',
#  'Suggested by',
#  'Venue',
#  'Writer(s)',
#  'alt_titles',
#  'imdb_link',
#  'title',
#  'url',
#  'year']

# %%
# create new column in df by extracting imdb ID from imdb url
wiki_movies_df['imdb_id'] = wiki_movies_df['imdb_link'].str.extract(r'(tt\d{7})')
print(len(wiki_movies_df))
# drop duplicate rows on imdb_id
wiki_movies_df.drop_duplicates(subset='imdb_id', inplace=True)
print(len(wiki_movies_df))
wiki_movies_df.head()
# Out:
# 7076
# 7033
#                                                  url  year  \
# 0  https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1  https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2   https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3    https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4      https://en.wikipedia.org/wiki/Almost_an_Angel  1990
#
#                                imdb_link                            title  \
# 0  https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1  https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2  https://www.imdb.com/title/tt0099005/                      Air America
# 3  https://www.imdb.com/title/tt0099012/                            Alice
# 4  https://www.imdb.com/title/tt0099018/                  Almost an Angel
#
#                       Story by  \
# 0  [David Arnott, James Cappe]
# 1                          NaN
# 2                          NaN
# ...

# %%
# get list of columns with and number of null values
[[column, wiki_movies_df[column].isnull().sum()] for column in wiki_movies_df.columns]
# Out:
# [['url', 0],
#  ['year', 0],
#  ['imdb_link', 0],
#  ['title', 1],
#  ['Story by', 6036],
#  ['Based on', 4852],
#  ['Starring', 182],
#  ['Narrated by', 6752],
#  ['Cinematography', 691],
#  ['Release date', 32],
#  ['Country', 236],
#  ['Language', 244],
#  ['Budget', 2295],
#  ['Box office', 1548],
#  ['Director', 0],
#  ['Distributor', 357],
#  ['Editor(s)', 548],
#  ['Composer(s)', 518],
#  ['Producer(s)', 202],
#  ['Production company(s)', 1678],
#  ['Length', 139],
#  ['Writer(s)', 203],
#  ['Genre', 6923],
#  ['Original language(s)', 6875],
#  ['Original network', 6908],
#  ['Executive producer(s)', 6936],
#  ['Production location(s)', 6986],
#  ['Picture format', 6969],
#  ['Audio format', 6972],
#  ['Followed by', 7024],
#  ['Created by', 7023],
#  ['Preceded by', 7023],
#  ['Suggested by', 7032],
#  ['alt_titles', 7012],
#  ['Recorded', 7031],
#  ['Venue', 7032],
#  ['Label', 7031],
#  ['Animation by', 7031],
#  ['Color process', 7032],
#  ['imdb_id', 0]]

# %%
# create list of columns that have less that 90% null valuses
columns_to_keep = [column for column in wiki_movies_df.columns if wiki_movies_df[column].isnull().sum() < len(wiki_movies_df) * .9]

# %%
# create dataframe with only columns_to_keep
wiki_movies_df = wiki_movies_df[columns_to_keep]
wiki_movies_df.head()
# Out:
#                                                  url  year  \
# 0  https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1  https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2   https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3    https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4      https://en.wikipedia.org/wiki/Almost_an_Angel  1990
#
#                                imdb_link                            title  \
# 0  https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1  https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2  https://www.imdb.com/title/tt0099005/                      Air America
# 3  https://www.imdb.com/title/tt0099012/                            Alice
# 4  https://www.imdb.com/title/tt0099018/                  Almost an Angel
#
#                       Story by  \
# 0  [David Arnott, James Cappe]
# 1                          NaN
# 2                          NaN
# 3                          NaN
# ...

# %%
wiki_movies_df.dtypes
# Out:
# url                      object
# year                      int64
# imdb_link                object
# title                    object
# Story by                 object
# Based on                 object
# Starring                 object
# Cinematography           object
# Release date             object
# Country                  object
# Language                 object
# Budget                   object
# Box office               object
# Director                 object
# Distributor              object
# Editor(s)                object
# Composer(s)              object
# Producer(s)              object
# Production company(s)    object
# Length                   object
# Writer(s)                object
# imdb_id                  object
# dtype: object

# %%
box_office = wiki_movies_df['Box office'].dropna()
len(box_office)
# Out:
# 5485

# %%
# find which amounts in box_office are not strings using lambda
box_office[box_office.map(lambda x: type(x) != str)]
# Out:
# 34                           [US$, 4,212,828]
# 54      [$6,698,361 (, United States, ), [2]]
# 74                    [$6,488,144, (US), [1]]
# 126                [US$1,531,489, (domestic)]
# 130                          [US$, 4,803,039]
#                         ...
# 6980               [$99.6, million, [4], [5]]
# 6994                   [$365.6, million, [1]]
# 6995                         [$53.8, million]
# 7015                     [$435, million, [7]]
# 7048                   [$529.3, million, [4]]
# Name: Box office, Length: 135, dtype: object

# %%
# if entry in box_office is a list, join the elements into a string
box_office= box_office.apply(lambda x: ' '.join(x) if type(x) == list else x)

# %%
box_office
# Out:
# 0          $21.4 million
# 1           $2.7 million
# 2            $57,718,089
# 3             $7,331,647
# 4       $6,939,946 (USA)
#               ...
# 7070       $19.4 million
# 7071       $41.9 million
# 7072       $76.1 million
# 7073       $38.4 million
# 7074        $5.5 million
# Name: Box office, Length: 5485, dtype: object

# %%
# build regex for box_offices in $___ (m/b)illion form
form_one = r'\$\d+\.?\d*\s*[mb]illion'

# %%
# find how many entries are form one
box_office.str.contains(form_one, flags=re.IGNORECASE).sum()
# Out:
# 3896

# %%
# build regex for $___,___ form
form_two = r'\$\d{1,3}(?:,\d{3})+'

# %%
# find how many entries are form two
box_office.str.contains(form_two, flags=re.IGNORECASE).sum()
# Out:
# 1544

# %%
# found out how many entries match both neither form

matches_form_one = box_office.str.contains(form_one, flags=re.IGNORECASE)
matches_form_two = box_office.str.contains(form_two, flags=re.IGNORECASE)
matches_form_two
# Out:
# 0       False
# 1       False
# 2        True
# 3        True
# 4        True
#         ...
# 7070    False
# 7071    False
# 7072    False
# 7073    False
# 7074    False
# Name: Box office, Length: 5485, dtype: bool

# %%
box_office[~matches_form_one & ~matches_form_two]
# Out:
# 34                         US$ 4,212,828
# 79                              $335.000
# 110                   $4.35-4.37 million
# 130                        US$ 4,803,039
# 600                           $5000 (US)
# 731                         $ 11,146,270
# 957                             $ 50,004
# 1070                          35,254,617
# 1147    $ 407,618 (U.S.) (sub-total) [1]
# 1446                        $ 11,829,959
# 1480                          £3 million
# 1611                            $520.000
# 1865                        ¥1.1 billion
# 2032                                 N/A
# 2091                                $309
# 2130               US$ 171.8 million [9]
# 2257                   US$ 3,395,581 [1]
# 2263            $ 1,223,034 ( domestic )
# 2347                            $282.175
# 2638            $ 104,883 (US sub-total)
# 2665         926,423 admissions (France)
# 2697      $ 1.7 million (US) (sub-total)
# 2823                            $414.000
# ...

# %%
# edit regex for box_offices to match pattern variations
form_one = r'\$\s*\d+\.?\d*\s*[mb]illi?on'
form_two = r'\$\s*\d{1,3}(?:[,\.]\d{3})+(?![mb]illion)'

# %%
# find how many entries are form one
box_office.str.contains(form_one, flags=re.IGNORECASE).sum()
# Out:
# 3903

# %%
# find how many entries are form two
box_office.str.contains(form_two, flags=re.IGNORECASE).sum()
# Out:
# 1595

# %%
# found out how many entries match both neither form

matches_form_one = box_office.str.contains(form_one, flags=re.IGNORECASE)
matches_form_two = box_office.str.contains(form_two, flags=re.IGNORECASE)

# %%
box_office[~matches_form_one & ~matches_form_two]
# Out:
# 110              $4.35-4.37 million
# 600                      $5000 (US)
# 1070                     35,254,617
# 1480                     £3 million
# 1865                   ¥1.1 billion
# 2032                            N/A
# 2091                           $309
# 2665    926,423 admissions (France)
# 3088      $32 [2] –33.1 million [1]
# 3631                            TBA
# 3859             $38.9–40.3 million
# 3879       CN¥3.650 million (China)
# 4116                     £7,385,434
# 4261             $20.7–23.9 million
# 4306                         $20-30
# 4561        $45.2k (only in Turkey)
# 5447                          £2.56
# 5784                       413 733$
# 6013                        Unknown
# 6145             $17.5–18.4 million
# 6234             $41.8–41.9 million
# 6369                          $111k
# 6370                           $588
# 6593                 less than $372
# 6843                        8 crore
# Name: Box office, dtype: object

# %%
# replace box_office amounts written as range
box_office = box_office.str.replace(r'\$.*[-—–](?![a-z])', '$', regex=True)

# %%
box_office[~matches_form_one & ~matches_form_two]
# Out:
# 110                   $4.37 million
# 600                      $5000 (US)
# 1070                     35,254,617
# 1480                     £3 million
# 1865                   ¥1.1 billion
# 2032                            N/A
# 2091                           $309
# 2665    926,423 admissions (France)
# 3088              $33.1 million [1]
# 3631                            TBA
# 3859                  $40.3 million
# 3879       CN¥3.650 million (China)
# 4116                     £7,385,434
# 4261                  $23.9 million
# 4306                            $30
# 4561        $45.2k (only in Turkey)
# 5447                          £2.56
# 5784                       413 733$
# 6013                        Unknown
# 6145                  $18.4 million
# 6234                  $41.9 million
# 6369                          $111k
# 6370                           $588
# 6593                 less than $372
# 6843                        8 crore
# Name: Box office, dtype: object

# %%
box_office
# Out:
# 0          $21.4 million
# 1           $2.7 million
# 2            $57,718,089
# 3             $7,331,647
# 4       $6,939,946 (USA)
#               ...
# 7070       $19.4 million
# 7071       $41.9 million
# 7072       $76.1 million
# 7073       $38.4 million
# 7074        $5.5 million
# Name: Box office, Length: 5485, dtype: object

# %%
# extract only the values
box_office.str.extract(f'({form_one}|{form_two})').head(20)
# Out:
#                  0
# 0    $21.4 million
# 1     $2.7 million
# 2      $57,718,089
# 3       $7,331,647
# 4       $6,939,946
# 9         $855,810
# 10  $195.3 million
# 11   $53.2 million
# 12   $15.7 million
# 13   $52.1 million
# 14  $244.5 million
# 15     $12,626,043
# 17     $19,740,070
# 18    $138,697,012
# 20      $1,292,323
# 21    $8.2 million
# 22   $15.6 million
# 24      $2,070,871
# 25   $27.6 million
# 27         $10,173

# %%
# define function to turn extracted values into floats
def parse_dollars(s):
    # if is is not a string, return NaN
    if type(s) != str:
        return np.nan
    
    # if input is of the form $###.# million
    if re.match(r'\$\s*\d+\.?\d*\s*milli?on', s, flags=re.IGNORECASE):
        
        # remove dollar sign and "million"
        s = re.sub('\$|\s|[a-zA-Z]', '', s)
        
        # convert to float and mulitply by a million
        value = float(s) * 10**6
        
        # return value
        return value
    
    # if imput is of the form $###.# billion
    elif re.match(r'\$\s*\d+\.?\d*\s*billi?on', s, flags=re.IGNORECASE):
        
        # remove dollar sign and "billion"
        s = re.sub('\$|\s|[a-zA-Z]', '', s)
        
        # convert to float and mulitply by a billion
        value = float(s) * 10**9
        
        # return value
        return value
    
    # if input is of the form $###,###,###
    elif re.match(r'\$\s*\d{1,3}(?:[,\.]\d{3})+(?![mb]illion)', s, flags=re.IGNORECASE):
        
        # remove dollar sign and commas
        s = re.sub('\$|,','', s)
        
        # convert to float
        value = float(s)
        
        # return value
        return value
    # otherwise, return NaN
    else:
        return np.nan

# %%
# apply the parse dollars function to the extracted values from box_office and set values to box_office column in wiki_movies_df
wiki_movies_df['box_office'] = box_office.str.extract(f'({form_one}|{form_two})', flags=re.IGNORECASE)[0].apply(parse_dollars)

# %%
wiki_movies_df['box_office']
# Out:
# 0       21400000.0
# 1        2700000.0
# 2       57718089.0
# 3        7331647.0
# 4        6939946.0
#            ...
# 7071    41900000.0
# 7072    76100000.0
# 7073    38400000.0
# 7074     5500000.0
# 7075           NaN
# Name: box_office, Length: 7033, dtype: float64

# %%
wiki_movies_df.drop('Box office', axis=1, inplace=True)

# %%
# parse budget
#create budget variable
budget = wiki_movies_df['Budget'].dropna()
budget
# Out:
# 0        $20 million
# 1         $6 million
# 2        $35 million
# 3        $12 million
# 4        $25 million
#             ...
# 7070    €4.3 million
# 7071     $42 million
# 7072     $60 million
# 7073     $20 million
# 7074      $9 million
# Name: Budget, Length: 4738, dtype: object

# %%
# convert lists to strings
budget = budget.map(lambda x: ' '.join(x) if type(x) == list else x)

# %%
budget = budget.str.replace(r'\$.*[-—–](?![a-z])', '$', regex=True)

# %%
# find how many entries are form one
budget.str.contains(form_one, flags=re.IGNORECASE).sum()
# Out:
# 4363

# %%
# found out how many entries match both neither form

matches_form_one = budget.str.contains(form_one, flags=re.IGNORECASE)
matches_form_two = budget.str.contains(form_two, flags=re.IGNORECASE)

# %%
budget[~matches_form_one & ~matches_form_two]
# Out:
# 136                         Unknown
# 204     60 million Norwegian Kroner
# 478                         Unknown
# 973             $34 [3] [4] million
# 1126               $120 [4] million
# 1226                        Unknown
# 1278                            HBO
# 1374                     £6,000,000
# 1397                     13 million
# 1480                   £2.8 million
# 1734                   CAD2,000,000
# 1913     PHP 85 million (estimated)
# 1948                    102,888,900
# 1953                   3,500,000 DM
# 1973                     ₤2,300,874
# 2281                     $14 milion
# 2451                     ₤6,350,000
# 3144                   € 40 million
# 3360               $150 [6] million
# 3418                        $218.32
# 3802                   £4.2 million
# 3906                            N/A
# 3959                    760,000 USD
# 4470                       19 crore
# 4641                    £17 million
# 5034              $$200 [4] million
# ...

# %%
budget = budget.str.replace(r'\[\d+\]\s*', '', regex=True)
len(budget[~matches_form_one& ~matches_form_two ])
# Out:
# 38

# %%
# apply the parse dollars function to the extracted values from budget and set values to budget column in wiki_movies_df
wiki_movies_df['budget'] = budget.str.extract(f'({form_one}|{form_two})', flags=re.IGNORECASE)[0].apply(parse_dollars)

# %%
wiki_movies_df['budget']
# Out:
# 0       20000000.0
# 1        6000000.0
# 2       35000000.0
# 3       12000000.0
# 4       25000000.0
#            ...
# 7071    42000000.0
# 7072    60000000.0
# 7073    20000000.0
# 7074     9000000.0
# 7075           NaN
# Name: budget, Length: 7033, dtype: float64

# %%
wiki_movies_df.drop('Budget', axis=1, inplace=True)

# %%
# Parse release date
# create release date variable from wiki_movies column
release_date = wiki_movies_df["Release date"].dropna().apply(lambda x: ' '.join(x) if type(x) == list else x) # join lists into string

# %%
release_date
# Out:
# 0                            July 11, 1990 ( 1990-07-11 )
# 1       May 17, 1990 ( 1990-05-17 ) (Cannes Film Marke...
# 2                          August 10, 1990 ( 1990-08-10 )
# 3                        December 25, 1990 ( 1990-12-25 )
# 4                                       December 19, 1990
#                               ...
# 7071     December 25, 2018 ( 2018-12-25 ) (United States)
# 7072    December 11, 2018 ( 2018-12-11 ) ( Samuel Gold...
# 7073    November 8, 2018 ( 2018-11-08 ) ( AFI Fest ) D...
# 7074    August 31, 2018 ( 2018-08-31 ) ( Telluride ) D...
# 7075                      28 December 2018 ( 2018-12-28 )
# Name: Release date, Length: 7001, dtype: object

# %%
# create regex for different date forms
date_form_one = r'(?:January|February|March|April|May|June|July|August|September|October|November|December)\s\d+,\s\d{4}'
date_form_two = r'\d{4}.\d{2}.\d{2}'
date_form_three = r'(?:January|February|March|April|May|June|July|August|September|October|November|December)\s\d{4}'
date_form_four = r'\d{4}'

# %%
# create matches for each form to find any forms outside these
matches_date_form_one = release_date.str.contains(date_form_one, flags=re.IGNORECASE)
matches_date_form_two = release_date.str.contains(date_form_two, flags=re.IGNORECASE)
matches_date_form_three = release_date.str.contains(date_form_three, flags=re.IGNORECASE)
matches_date_form_four = release_date.str.contains(date_form_four, flags=re.IGNORECASE)
release_date[~matches_date_form_one & ~matches_date_form_two & ~matches_date_form_three & ~matches_date_form_four]
# Out:
# Series([], Name: Release date, dtype: object)

# %%
release_date.str.extract(f'({date_form_one}|{date_form_two}|{date_form_three}|{date_form_four})', flags=re.IGNORECASE)
# Out:
#                       0
# 0         July 11, 1990
# 1          May 17, 1990
# 2       August 10, 1990
# 3     December 25, 1990
# 4     December 19, 1990
# ...                 ...
# 7071  December 25, 2018
# 7072  December 11, 2018
# 7073   November 8, 2018
# 7074    August 31, 2018
# 7075      December 2018
#
# [7001 rows x 1 columns]

# %%
wiki_movies_df['release date'] = pd.to_datetime(release_date.str.extract(f'({date_form_one}|{date_form_two}|{date_form_three}|{date_form_four})')[0], infer_datetime_format=True)

# %%
# drop old Release Date column
wiki_movies_df.drop('Release date', axis=1, inplace=True)

# %%
# parse length
# make variable for length
length = wiki_movies_df['Length'].dropna().apply(lambda x: ' '.join(x) if type(x) == list else x)

# %%
length
# Out:
# 0                                 102 minutes
# 1                                 114 minutes
# 2                                 113 minutes
# 3                                 106 minutes
# 4                                  95 minutes
#                         ...
# 7071                               90 minutes
# 7072                              132 minutes
# 7073                              120 minutes
# 7074                              123 minutes
# 7075    Variable; 90 minutes for default path
# Name: Length, Length: 6894, dtype: object

# %%
# find if any lengths are not '123 minutes' form
length.str.contains(r'\d*\s*minutes$', flags=re.IGNORECASE).sum()
# Out:
# 6535

# %%
length[length.str.contains(r'\d*\s*minutes$', flags=re.IGNORECASE) != True]
# Out:
# 9                                                 102 min
# 26                                                 93 min
# 28                                                32 min.
# 34                                                101 min
# 35                                                 97 min
#                               ...
# 6500       114 minutes [1] 120 minutes (extended edition)
# 6643                                             104 mins
# 6709    90 minutes (theatrical) [1] 91 minutes (unrate...
# 7057    108 minutes (Original cut) 98 minutes (UK cut)...
# 7075                Variable; 90 minutes for default path
# Name: Length, Length: 359, dtype: object

# %%
# expand regex to only find beginning of string and include m abbr. for minutes
length.str.contains(r'^\d*\s*m', flags=re.IGNORECASE).sum()
# Out:
# 6877

# %%
length[length.str.contains(r'^\d*\s*m', flags=re.IGNORECASE) != True]
# Out:
# 668                     UK:84 min (DVD version) US:86 min
# 727                         78-102 min (depending on cut)
# 840                       Varies (79 [3] –84 [1] minutes)
# 1347                                              25 : 03
# 1443    United States: 77 minutes Argentina: 94 minute...
# 1499                                            1hr 35min
# 1551                                               varies
# 1774                    Netherlands:96 min, Canada:95 min
# 1777                                       approx. 14 min
# 2273                                           1 h 43 min
# 2993                                               1h 48m
# 3925                                              4 hours
# 4425    US domestic version: 86 minutes Original versi...
# 4967    Theatrical cut: 97 minutes Unrated cut: 107 mi...
# 5424                    115 [1] /123 [2] /128 [3] minutes
# 5447                                    1 hour 32 minutes
# ...

# %%
# expand regex to only find beginning of string and include m abbr. for minutes
length.str.contains(r'\d*\s*m', flags=re.IGNORECASE).sum()
# Out:
# 6891

# %%
length[length.str.contains(r'\d*\s*m', flags=re.IGNORECASE) != True]
# Out:
# 1347    25 : 03
# 1551     varies
# 3925    4 hours
# Name: Length, dtype: object

# %%
# make df by extracting length values
length_extract = length.str.extract(r'(\d+)\s*ho?u?r?s?\s*(\d*)|(\d*)\s*m')

# %%
# convert strings to numeric values
length_extract = length_extract.apply(lambda col: pd.to_numeric(col, errors='coerce')).fillna(0)

# %%
# extract either hours and minutes capture groups and convert to minutes if only minutes column == 0, else extract minutes column
wiki_movies_df['running_time'] = length_minutes = length_extract.apply(lambda row: row[0]*60 + row[1] if row[2] == 0 else row[2], axis = 1)

# %%
# drop old Length column
wiki_movies_df.drop('Length', axis=1, inplace=True)

# %%
kaggle_meta_data.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
kaggle_meta_data.dtypes
# Out:
# adult                     object
# belongs_to_collection     object
# budget                    object
# genres                    object
# homepage                  object
# id                        object
# imdb_id                   object
# original_language         object
# original_title            object
# overview                  object
# popularity                object
# poster_path               object
# production_companies      object
# production_countries      object
# release_date              object
# revenue                  float64
# runtime                  float64
# spoken_languages          object
# status                    object
# tagline                   object
# title                     object
# video                     object
# vote_average             float64
# vote_count               float64
# dtype: object

# %%
# check if all valuse in adult are True or False
kaggle_meta_data['adult'].value_counts()
# Out:
# False                                                                                                                             45454
# True                                                                                                                                  9
#  Rune Balot goes to a casino connected to the October corporation to try to wrap up her case once and for all.                        1
#  Avalanche Sharks tells the story of a bikini contest that turns into a horrifying affair when it is hit by a shark avalanche.        1
#  - Written by Ørnås                                                                                                                   1
# Name: adult, dtype: int64

# %%
kaggle_meta_data[~kaggle_meta_data['adult'].isin(['True','False'])]
# Out:
#                                                    adult  \
# 19730                                 - Written by Ørnås
# 29503   Rune Balot goes to a casino connected to the ...
# 35587   Avalanche Sharks tells the story of a bikini ...
#
#       belongs_to_collection                            budget  \
# 19730              0.065736  /ff9qCepilowshEtG2GYWwzt2bs4.jpg
# 29503              1.931659  /zV8bHuSL6WXoD6FWogP9j4x80bL.jpg
# 35587              2.185485  /zaSf5OG7V8X8gqFvly88zDdRm46.jpg
#
#                                                   genres  \
# 19730  [{'name': 'Carousel Productions', 'id': 11176}...
# 29503  [{'name': 'Aniplex', 'id': 2883}, {'name': 'Go...
# 35587  [{'name': 'Odyssey Media', 'id': 17161}, {'nam...
#
#                                                 homepage          id imdb_id  \
# 19730  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...  1997-08-20       0
# 29503  [{'iso_3166_1': 'US', 'name': 'United States o...  2012-09-29       0
# ...

# %%
# keep only movies where adult is False
kaggle_meta_data = kaggle_meta_data[kaggle_meta_data['adult']== 'False'].drop('adult', axis='columns')

# %%
# parse video column
# check data types
kaggle_meta_data['video'].value_counts()
# Out:
# False    45358
# True        93
# Name: video, dtype: int64

# %%
# convert object to boolean datatype
kaggle_meta_data['video'] = kaggle_meta_data['video'] == 'True'

# %%
kaggle_meta_data['video'].dtypes
# Out:
# dtype('bool')

# %%
# convert budget to int
kaggle_meta_data['budget'] = kaggle_meta_data['budget'].astype(int)

# %%
# convert id to numeric
kaggle_meta_data['id'] = pd.to_numeric(kaggle_meta_data['id'], errors='raise')

# %%
# convert popularity to numeric
kaggle_meta_data['popularity'] = pd.to_numeric(kaggle_meta_data['popularity'], errors='raise')

# %%
# conver release date to datetime
kaggle_meta_data['release_date'] = pd.to_datetime(kaggle_meta_data['release_date'])

# %%
# clean ratings df
ratings.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26024289 entries, 0 to 26024288
# Data columns (total 4 columns):
#  #   Column     Non-Null Count     Dtype
# ---  ------     --------------     -----
#  0   userId     26024289 non-null  int64
#  1   movieId    26024289 non-null  int64
#  2   rating     26024289 non-null  float64
#  3   timestamp  26024289 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 794.2 MB

# %%
# convert timestamp to datetime
ratings['timestamp'] = pd.to_datetime(ratings['timestamp'], unit='s')

# %%
# parse rating column
# plot histogram and get stats on central tendency
pd.options.display.float_format = '{:20,.2f}'.format
ratings['rating'].plot(kind='hist')
ratings['rating'].describe()
# Out:
# count          26,024,289.00
# mean                    3.53
# std                     1.07
# min                     0.50
# 25%                     3.00
# 50%                     3.50
# 75%                     4.00
# max                     5.00
# Name: rating, dtype: float64

# %%
# merge wiki and kaggle dataframes
movies_df = pd.merge(wiki_movies_df, kaggle_meta_data, on='imdb_id', suffixes=['_wiki','_kaggle'])

# %%
movies_df.head(2)
# Out:
#                                                  url  year  \
# 0  https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1  https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
#
#                                imdb_link                       title_wiki  \
# 0  https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1  https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
#
#                       Story by  \
# 0  [David Arnott, James Cappe]
# 1                          NaN
#
#                                             Based on  \
# 0                        [Characters, by Rex Weiner]
# 1  [the novel, After Dark, My Sweet, by, Jim Thom...
#
#                                             Starring Cinematography  \
# 0  [Andrew Dice Clay, Wayne Newton, Priscilla Pre...    Oliver Wood
# 1  [Jason Patric, Rachel Ward, Bruce Dern, George...   Mark Plummer
#
#          Country Language  ... release_date              revenue  \
# ...

# %%
movies_df.columns.tolist()
# Out:
# ['url',
#  'year',
#  'imdb_link',
#  'title_wiki',
#  'Story by',
#  'Based on',
#  'Starring',
#  'Cinematography',
#  'Country',
#  'Language',
#  'Director',
#  'Distributor',
#  'Editor(s)',
#  'Composer(s)',
#  'Producer(s)',
#  'Production company(s)',
#  'Writer(s)',
#  'imdb_id',
#  'box_office',
#  'budget_wiki',
#  'release date',
#  'running_time',
#  'belongs_to_collection',
#  'budget_kaggle',
#  'genres',
#  'homepage',
#  'id',
#  'original_language',
#  'original_title',
#  'overview',
#  'popularity',
#  'poster_path',
#  'production_companies',
#  'production_countries',
#  'release_date',
#  'revenue',
#  'runtime',
#  'spoken_languages',
#  'status',
#  'tagline',
#  'title_kaggle',
#  'video',
#  'vote_average',
#  'vote_count']

# %%
# redundant columns from merging:
# Wiki                   Movielens                    Resolution
# ------------------------------------------------------------------------------
# title_wiki             title_kaggle                 Drop title_wiki
# running_time           runtime                      Keep runtime, fill missing values with running_time
# release date           release_date                 Drop release date
# Production company(s)  production_companies         Drop Production company(s)
# box_office             revenue                      Keep revenue, fill missing values with box_office
# Language               original_language            Drop Language
# budget_wiki            budget_kaggle                Keep budget_kaggle, fill missing values with budget_wiki

# %%
# compare title columns
movies_df[['title_wiki','title_kaggle']]
# Out:
#                            title_wiki                     title_kaggle
# 0     The Adventures of Ford Fairlane  The Adventures of Ford Fairlane
# 1                After Dark, My Sweet             After Dark, My Sweet
# 2                         Air America                      Air America
# 3                               Alice                            Alice
# 4                     Almost an Angel                  Almost an Angel
# ...                               ...                              ...
# 6047                A Fantastic Woman                A Fantastic Woman
# 6048                       Permission                       Permission
# 6049                         Loveless                         Loveless
# 6050                           Gemini                           Gemini
# 6051  How to Talk to Girls at Parties  How to Talk to Girls at Parties
#
# [6052 rows x 2 columns]

# %%
movies_df[['title_wiki','title_kaggle']][movies_df['title_wiki']!=movies_df['title_kaggle']]
# Out:
#                                            title_wiki  \
# 27                                          China Cry
# 36               Daddy's Dyin' ...Who's Got the Will?
# 38                          The Dark Side of the Moon
# 42                                      Delta Force 2
# 48      DuckTales the Movie:Treasure of the Lost Lamp
# ...                                               ...
# 5956                                            Chips
# 5971                                            Spark
# 5994  Pirates of the Caribbean:Dead Men Tell No Tales
# 6023       Valerian and the Cityof a Thousand Planets
# 6028            An Inconvenient Sequel:Truth to Power
#
#                                           title_kaggle
# 27                             China Cry: A True Story
# 36                Daddy's Dyin'... Who's Got the Will?
# 38                           The Dark Side of The Moon
# 42             Delta Force 2: The Colombian Connection
# ...

# %%
# check if any null/missing in kaggle title
movies_df[(movies_df['title_kaggle']=='')|(movies_df['title_kaggle'].isnull())]
# Out:
# Empty DataFrame
# Columns: [url, year, imdb_link, title_wiki, Story by, Based on, Starring, Cinematography, Country, Language, Director, Distributor, Editor(s), Composer(s), Producer(s), Production company(s), Writer(s), imdb_id, box_office, budget_wiki, release date, running_time, belongs_to_collection, budget_kaggle, genres, homepage, id, original_language, original_title, overview, popularity, poster_path, production_companies, production_countries, release_date, revenue, runtime, spoken_languages, status, tagline, title_kaggle, video, vote_average, vote_count]
# Index: []
#
# [0 rows x 44 columns]

# %%
# no missing/null in title_kaggle, so drop title wiki
movies_df.drop('title_wiki',axis=1, inplace=True)

# %%
# compare running time and runtime columns
movies_df[['running_time','runtime']]
# Out:
#              running_time              runtime
# 0                  102.00               104.00
# 1                  114.00               114.00
# 2                  113.00               112.00
# 3                  106.00               102.00
# 4                   95.00                95.00
# ...                   ...                  ...
# 6047               104.00               104.00
# 6048                96.00                96.00
# 6049               127.00               128.00
# 6050                92.00                92.00
# 6051               102.00               102.00
#
# [6052 rows x 2 columns]

# %%
# plot scatterplot to compare runtime columns, fill na with 0
movies_df.fillna(0).plot(kind='scatter', x='running_time', y='runtime')
# Out:
# <AxesSubplot:xlabel='running_time', ylabel='runtime'>

# %%
# plot scatterplot to compare budget columns, fill na with 0
movies_df.fillna(0).plot(kind='scatter', x='budget_wiki', y='budget_kaggle')
# Out:
# <AxesSubplot:xlabel='budget_wiki', ylabel='budget_kaggle'>

# %%
# plot scatterplot to compare box_office/revenue columns, fill na with 0
movies_df.fillna(0).plot(kind='scatter', x='box_office', y='revenue')
# Out:
# <AxesSubplot:xlabel='box_office', ylabel='revenue'>

# %%
# filter out box office < 1 billion to improve scale of plot
movies_df.fillna(0)[movies_df['box_office']<10**9].plot(kind='scatter', x='box_office', y='revenue')
# Out:
# <AxesSubplot:xlabel='box_office', ylabel='revenue'>

# %%
# plot release date columns as line plot to compare
movies_df[['release date','release_date']].plot(x='release date', y='release_date', style='.')
# Out:
# <AxesSubplot:xlabel='release date'>

# %%
# check the outlier date
movies_df[(movies_df['release date']>'1996-01-01') & (movies_df['release_date']<'1965-01-01')]
# Out:
#                                             url  year  \
# 3607  https://en.wikipedia.org/wiki/The_Holiday  2006
#
#                                    imdb_link Story by Based on  \
# 3607  https://www.imdb.com/title/tt00457939/      NaN      NaN
#
#                                                Starring Cinematography  \
# 3607  [Kate Winslet, Cameron Diaz, Jude Law, Jack Bl...    Dean Cundey
#
#             Country Language      Director  ... release_date  \
# 3607  United States  English  Nancy Meyers  ...   1953-08-28
#
#                   revenue              runtime  \
# 3607        30,500,000.00               118.00
#
#                               spoken_languages    status  \
# 3607  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                 tagline  \
# 3607  Pouring out of impassioned pages...brawling th...
#
#                title_kaggle  video         vote_average           vote_count
# ...

# %%
# that data is corrupted, so get index and drop row
movies_df[(movies_df['release date']>'1996-01-01') & (movies_df['release_date']<'1965-01-01')].index
# Out:
# Int64Index([3607], dtype='int64')

# %%
movies_df = movies_df.drop(movies_df[(movies_df['release date']>'1996-01-01') & (movies_df['release_date']<'1965-01-01')].index)

# %%
# check for null values
# movies_df[movies_df['release date'].isnull()]
movies_df[['release date', 'release_date']].isnull().sum()
# Out:
# release date    11
# release_date     0
# dtype: int64

# %%
# compare language columns
movies_df[['Language','original_language']]
# Out:
#             Language original_language
# 0            English                en
# 1            English                en
# 2     [English, Lao]                en
# 3            English                en
# 4            English                en
# ...              ...               ...
# 6047         Spanish                es
# 6048         English                en
# 6049         Russian                ru
# 6050         English                en
# 6051         English                en
#
# [6051 rows x 2 columns]

# %%
movies_df[['Language','original_language']].isnull().sum()
# Out:
# Language             134
# original_language      0
# dtype: int64

# %%
# convert lists in 'Language' to tuples
movies_df['Language'].apply(lambda x: tuple(x) if type(x)==list else x).value_counts(dropna=False)
# Out:
# English                             5479
# NaN                                  134
# (English, Spanish)                    68
# (English, French)                     35
# (English, Japanese)                   25
#                                     ...
# (English, Afrikaans, German)           1
# (English, Navajo)                      1
# (Korean, English)                      1
# (Chinese, English)                     1
# (English, French, Chinese, Urdu)       1
# Name: Language, Length: 198, dtype: int64

# %%
movies_df['original_language'].value_counts(dropna=False)
# Out:
# en    5987
# fr      16
# es      10
# it       8
# de       6
# pt       4
# ja       4
# zh       4
# hi       2
# da       2
# ab       1
# ru       1
# tr       1
# ar       1
# cn       1
# he       1
# ko       1
# sv       1
# Name: original_language, dtype: int64

# %%
# compare Production Company columns
movies_df[['Production company(s)','production_companies']]
# Out:
#                                   Production company(s)  \
# 0                                       Silver Pictures
# 1                                       Avenue Pictures
# 2                 [Carolco Pictures, IndieProd Company]
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6047                           [Fabula, Komplizen Film]
# 6048                           Ball & Chain Productions
# 6049          [Arte France Cinéma, Why Not Productions]
# 6050  [Film Science, Rough House Pictures, Syncopate...
# 6051         [HanWay Films, Little Punk, See-Saw Films]
#
#                                    production_companies
# 0     [{'name': 'Twentieth Century Fox Film Corporat...
# 1     [{'name': 'Avenue Pictures Productions', 'id':...
# 2     [{'name': 'IndieProd Company Productions', 'id...
# 3                [{'name': 'Orion Pictures', 'id': 41}]
# ...

# %%
# redundant columns from merging:
# Wiki                   Movielens                    Resolution
# ------------------------------------------------------------------------------
# title_wiki             title_kaggle                 Drop title_wiki
# running_time           runtime                      Keep runtime, fill missing values with running_time
# release date           release_date                 Drop release date
# Production company(s)  production_companies         Drop Production company(s)
# box_office             revenue                      Keep revenue, fill missing values with box_office
# Language               original_language            Drop Language
# budget_wiki            budget_kaggle                Keep budget_kaggle, fill missing values with budget_wiki

# %%
# drop the chosen columns from the df
movies_df.drop(columns=['release date', 'Production company(s)', 'Language'], inplace=True)

# %%
# create function to fill 0 values from Kaggle column with wiki column then drop wiki column
def fill_missing_kaggle_data(df, kaggle_column, wiki_column):
    df[kaggle_column] = df.apply(
        lambda row: row[wiki_column] if row[kaggle_column]==0 else row[kaggle_column], axis=1)
    df.drop(columns=wiki_column, inplace=True)

# %%
# run function on three columns as decided above
fill_missing_kaggle_data(movies_df, 'runtime','running_time')
fill_missing_kaggle_data(movies_df, 'revenue','box_office')
fill_missing_kaggle_data(movies_df, 'budget_kaggle','budget_wiki')
movies_df
# Out:
#                                                     url  year  \
# 0     https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1     https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2      https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3       https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4         https://en.wikipedia.org/wiki/Almost_an_Angel  1990
# ...                                                 ...   ...
# 6047    https://en.wikipedia.org/wiki/A_Fantastic_Woman  2018
# 6048    https://en.wikipedia.org/wiki/Permission_(film)  2018
# 6049      https://en.wikipedia.org/wiki/Loveless_(film)  2018
# 6050   https://en.wikipedia.org/wiki/Gemini_(2017_film)  2018
# 6051  https://en.wikipedia.org/wiki/How_to_Talk_to_G...  2018
#
#                                   imdb_link                     Story by  \
# 0     https://www.imdb.com/title/tt0098987/  [David Arnott, James Cappe]
# ...

# %%
# check value counts to check for columns with only 1 value
for col in movies_df.columns:
    lists_to_tuples = lambda x: tuple(x) if type(x) == list else x
    value_counts = movies_df[col].apply(lists_to_tuples).value_counts(dropna=False)
    num_values = len(value_counts)
    if num_values == 1:
        print(col)
# Out:
# video

# %%
# try list comprehension to check for columns with 1 value
cols = [col for col in movies_df.columns if len(movies_df[col].apply(lambda x: tuple(x) if type(x) == list else x).value_counts(dropna=False))==1]
cols
# Out:
# ['video']

# %%
movies_df['video'].value_counts(dropna=False)
# Out:
# False    6051
# Name: video, dtype: int64

# %%
# drop video column
movies_df.drop(columns='video', inplace=True)

# %%
# reorder columns
movies_df = movies_df.loc[:, ['imdb_id','id','title_kaggle','original_title','tagline','belongs_to_collection','url','imdb_link',
                       'runtime','budget_kaggle','revenue','release_date','popularity','vote_average','vote_count',
                       'genres','original_language','overview','spoken_languages','Country',
                       'production_companies','production_countries','Distributor',
                       'Producer(s)','Director','Starring','Cinematography','Editor(s)','Writer(s)','Composer(s)','Based on']]

# %%
# rename columns for consistency
movies_df.rename({'id':'kaggle_id',
                 'title_kaggle':'title',
                 'url':'wikipedia_url',
                 'budget_kaggle':'budget',
                 'Country':'country',
                 'Distributor':'distributor',
                 'Producer(s)':'producers',
                 'Director':'director',
                 'Starring':'starring',
                 'Cinematography':'cinematography',
                 'Editor(s)':'editor',
                 'Writer(s)':'writers',
                 'Composer(s)':'composer',
                 'Based on':'based_on'},axis=1, inplace=True)

# %%
# transform ratings dataframe
ratings.head()
# Out:
#    userId  movieId               rating           timestamp
# 0       1      110                 1.00 2015-03-09 22:52:09
# 1       1      147                 4.50 2015-03-09 23:07:15
# 2       1      858                 5.00 2015-03-09 22:52:03
# 3       1     1221                 5.00 2015-03-09 22:52:26
# 4       1     1246                 5.00 2015-03-09 22:52:36

# %%
ratings.tail()
# Out:
#           userId  movieId               rating           timestamp
# 26024284  270896    58559                 5.00 2009-10-31 23:26:04
# 26024285  270896    60069                 5.00 2009-10-31 23:33:52
# 26024286  270896    63082                 4.50 2009-10-31 23:29:24
# 26024287  270896    64957                 4.50 2009-11-01 00:06:30
# 26024288  270896    71878                 2.00 2009-10-31 23:30:58

# %%
# groupby movieID then rating
ratings.groupby(['movieId','rating'], as_index=False).count()
# Out:
#         movieId               rating  userId  timestamp
# 0             1                 0.50     441        441
# 1             1                 1.00     804        804
# 2             1                 1.50     438        438
# 3             1                 2.00    2083       2083
# 4             1                 2.50    1584       1584
# ...         ...                  ...     ...        ...
# 239376   176267                 4.00       1          1
# 239377   176269                 3.50       1          1
# 239378   176271                 5.00       1          1
# 239379   176273                 1.00       1          1
# 239380   176275                 3.00       1          1
#
# [239381 rows x 4 columns]

# %%
# pivot the table to make row for each movieId and column for rating with number of ratings as values
ratings_counts = ratings.groupby(['movieId','rating'], as_index=False).count().rename({'userId':'count'}, axis=1).pivot(index='movieId', columns='rating', values='count')
ratings_counts
# Out:
# rating                  0.50                 1.00                 1.50  \
# movieId
# 1                     441.00               804.00               438.00
# 2                     263.00               797.00               525.00
# 3                     169.00               772.00               233.00
# 4                      47.00               351.00                31.00
# 5                     237.00               785.00               270.00
# ...                      ...                  ...                  ...
# 176267                   nan                  nan                  nan
# 176269                   nan                  nan                  nan
# 176271                   nan                  nan                  nan
# 176273                   nan                 1.00                  nan
# 176275                   nan                  nan                  nan
#
# rating                  2.00                 2.50                 3.00  \
# movieId
# ...

# %%
# rename columns for clarity
ratings_counts.columns = [f'rating_{col}' for col in ratings_counts.columns]
ratings_counts
# Out:
#                   rating_0.5           rating_1.0           rating_1.5  \
# movieId
# 1                     441.00               804.00               438.00
# 2                     263.00               797.00               525.00
# 3                     169.00               772.00               233.00
# 4                      47.00               351.00                31.00
# 5                     237.00               785.00               270.00
# ...                      ...                  ...                  ...
# 176267                   nan                  nan                  nan
# 176269                   nan                  nan                  nan
# 176271                   nan                  nan                  nan
# 176273                   nan                 1.00                  nan
# 176275                   nan                  nan                  nan
#
#                   rating_2.0           rating_2.5           rating_3.0  \
# movieId
# ...

# %%
# merge movies_df and ratings_counts 
movies_with_ratings_df = movies_df.merge(ratings_counts, how='left', left_on='kaggle_id', right_index=True)

# %%
movies_with_ratings_df.head()
# Out:
#      imdb_id  kaggle_id                            title  \
# 0  tt0098987       9548  The Adventures of Ford Fairlane
# 1  tt0098994      25501             After Dark, My Sweet
# 2  tt0099005      11856                      Air America
# 3  tt0099012       8217                            Alice
# 4  tt0099018      25943                  Almost an Angel
#
#                     original_title                                  tagline  \
# 0  The Adventures of Ford Fairlane      Kojak. Columbo. Dirty Harry. Wimps.
# 1             After Dark, My Sweet          All they risked was everything.
# 2                      Air America  The few. The proud. The totally insane.
# 3                            Alice                                      NaN
# 4                  Almost an Angel                 Who does he think he is?
#
#   belongs_to_collection                                      wikipedia_url  \
# 0                   NaN  https://en.wikipedia.org/wiki/The_Adventures_o...
# ...

# %%
# replace NaN ratings with 0
movies_with_ratings_df[ratings_counts.columns] = movies_with_ratings_df[ratings_counts.columns].fillna(0)
movies_with_ratings_df.head()
# Out:
#      imdb_id  kaggle_id                            title  \
# 0  tt0098987       9548  The Adventures of Ford Fairlane
# 1  tt0098994      25501             After Dark, My Sweet
# 2  tt0099005      11856                      Air America
# 3  tt0099012       8217                            Alice
# 4  tt0099018      25943                  Almost an Angel
#
#                     original_title                                  tagline  \
# 0  The Adventures of Ford Fairlane      Kojak. Columbo. Dirty Harry. Wimps.
# 1             After Dark, My Sweet          All they risked was everything.
# 2                      Air America  The few. The proud. The totally insane.
# 3                            Alice                                      NaN
# 4                  Almost an Angel                 Who does he think he is?
#
#   belongs_to_collection                                      wikipedia_url  \
# 0                   NaN  https://en.wikipedia.org/wiki/The_Adventures_o...
# ...
